# %%
import cv2
import time
import os
from ultralytics import YOLO


# Initialize the camera
cap = cv2.VideoCapture(0)

# Define motion detection parameters
threshold = 30  # Threshold for detecting motion
min_contour_area = 500  # Minimum contour area for motion detection

# Initialize variables
prev_frame = None
prev_time = time.time()
capture_interval = 10  # Capture image every 10 seconds
save_dir = "saved_picture"  # Specify the directory to save images

# Create the directory if it doesn't exist
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

while True:
    # Read frame from camera
    ret, frame = cap.read()

    # Convert frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Blur the frame to reduce noise
    blurred_frame = cv2.GaussianBlur(gray_frame, (5, 5), 0)
    
    if prev_frame is None:
        prev_frame = blurred_frame
        continue

    # Calculate absolute difference between current frame and previous frame
    frame_diff = cv2.absdiff(prev_frame, blurred_frame)
    
    # Apply a threshold to the frame difference
    _, thresh = cv2.threshold(frame_diff, threshold, 255, cv2.THRESH_BINARY)
    
    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Check if any contour meets minimum area requirement
    for contour in contours:
        if cv2.contourArea(contour) > min_contour_area:
            # Motion detected
            
            image_path = os.path.join(save_dir, f"captured_image_{int(curr_time)}.jpg")
            cv2.imwrite(image_path, frame)
            print(f"Motion detected! Image saved to: {image_path}")
            prev_time = curr_time

            #detect
            # source=image_path
            # model = YOLO('best.pt')
            # model.predict(source=source, save=True, conf=0.5)
            # os.remove(image_path)
            #jeda 3 detik
            

    # Update previous frame
    prev_frame = blurred_frame

    # Check if it's time to capture image
    curr_time = time.time()
    if curr_time - prev_time >= capture_interval:
        # Save the image to specified directory
        image_path = os.path.join(save_dir, f"captured_image_{int(curr_time)}.jpg")
        cv2.imwrite(image_path, frame)
        print(f"Image saved to: {image_path}")
        prev_time = curr_time
        #for detect
        source=image_path
        model = YOLO('best.pt')
        model.predict(source=source, save=True, conf=0.5)
        # os.remove(image_path)


    # Display the frame
    cv2.imshow("Camera Feed", frame)

    # Check for key press to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Image saved to: saved_picture\captured_image_1710389665.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389665.jpg: 480x640 (no detections), 74.6ms
# Speed: 2.0ms preprocess, 74.6ms inference, 14.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict31
# Image saved to: saved_picture\captured_image_1710389675.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389675.jpg: 480x640 (no detections), 43.6ms
# Speed: 3.5ms preprocess, 43.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict32
# Image saved to: saved_picture\captured_image_1710389685.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389685.jpg: 480x640 (no detections), 38.9ms
# Speed: 3.0ms preprocess, 38.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict33
# Image saved to: saved_picture\captured_image_1710389695.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389695.jpg: 480x640 (no detections), 36.7ms
# Speed: 3.0ms preprocess, 36.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict34
# Motion detected! Image saved to: saved_picture\captured_image_1710389699.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389699.jpg: 480x640 (no detections), 39.4ms
# Speed: 6.0ms preprocess, 39.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict35
# Motion detected! Image saved to: saved_picture\captured_image_1710389701.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389701.jpg: 480x640 (no detections), 25.1ms
# Speed: 2.7ms preprocess, 25.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict36
# Motion detected! Image saved to: saved_picture\captured_image_1710389701.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389701.jpg: 480x640 (no detections), 25.2ms
# Speed: 3.0ms preprocess, 25.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict37
# Motion detected! Image saved to: saved_picture\captured_image_1710389701.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389701.jpg: 480x640 (no detections), 31.0ms
# Speed: 3.5ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict38
# Motion detected! Image saved to: saved_picture\captured_image_1710389701.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389701.jpg: 480x640 (no detections), 24.0ms
# Speed: 3.5ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict39
# Motion detected! Image saved to: saved_picture\captured_image_1710389701.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389701.jpg: 480x640 (no detections), 26.2ms
# Speed: 3.0ms preprocess, 26.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict40
# Motion detected! Image saved to: saved_picture\captured_image_1710389701.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389701.jpg: 480x640 (no detections), 23.8ms
# Speed: 3.0ms preprocess, 23.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict41
# Motion detected! Image saved to: saved_picture\captured_image_1710389709.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389709.jpg: 480x640 (no detections), 25.8ms
# Speed: 3.0ms preprocess, 25.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict42
# Motion detected! Image saved to: saved_picture\captured_image_1710389709.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389709.jpg: 480x640 (no detections), 26.6ms
# Speed: 3.0ms preprocess, 26.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict43
# Motion detected! Image saved to: saved_picture\captured_image_1710389709.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389709.jpg: 480x640 (no detections), 23.7ms
# Speed: 3.2ms preprocess, 23.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict44
# Motion detected! Image saved to: saved_picture\captured_image_1710389709.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389709.jpg: 480x640 (no detections), 24.7ms
# Speed: 3.0ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict45
# Motion detected! Image saved to: saved_picture\captured_image_1710389709.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389709.jpg: 480x640 (no detections), 24.6ms
# Speed: 2.0ms preprocess, 24.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict46
# Motion detected! Image saved to: saved_picture\captured_image_1710389709.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389709.jpg: 480x640 (no detections), 32.0ms
# Speed: 3.5ms preprocess, 32.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict47
# Motion detected! Image saved to: saved_picture\captured_image_1710389709.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389709.jpg: 480x640 (no detections), 26.5ms
# Speed: 3.0ms preprocess, 26.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict48
# Motion detected! Image saved to: saved_picture\captured_image_1710389709.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389709.jpg: 480x640 (no detections), 25.1ms
# Speed: 2.6ms preprocess, 25.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict49
# Motion detected! Image saved to: saved_picture\captured_image_1710389709.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389709.jpg: 480x640 (no detections), 24.5ms
# Speed: 2.5ms preprocess, 24.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict50
# Motion detected! Image saved to: saved_picture\captured_image_1710389709.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389709.jpg: 480x640 (no detections), 28.6ms
# Speed: 3.0ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict51
# Motion detected! Image saved to: saved_picture\captured_image_1710389709.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389709.jpg: 480x640 (no detections), 27.9ms
# Speed: 3.3ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict52
# Image saved to: saved_picture\captured_image_1710389724.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389724.jpg: 480x640 (no detections), 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict53
# Motion detected! Image saved to: saved_picture\captured_image_1710389724.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389724.jpg: 480x640 (no detections), 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict54
# Motion detected! Image saved to: saved_picture\captured_image_1710389732.jpg
#
# image 1/1 c:\Users\Jonathan Vito S\Desktop\MODEL TA\saved_picture\captured_image_1710389732.jpg: 480x640 (no detections), 36.6ms
# Speed: 3.6ms preprocess, 36.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict55

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('best.pt')

results = model(['saved_picture\captured_image_1710387233.jpg', 'saved_picture\captured_image_1710387229.jpg'])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    result.show()  # display to screen
    result.save(filename='result.jpg')  # save to disk
# Out:
# 0: 480x640 (no detections), 1: 480x640 (no detections), 94.8ms
# Speed: 4.2ms preprocess, 47.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
